# %%
import pandas as pd
import numpy as np


s = pd.Series([10, 15, 20, 25], index=['1', '2', '3', '4'])
print("\nSeries:")
print(s)
data = {
    'Name': ['mithra', 'srija', 'samveda', 'mohana'],
    'Age': [20, 28, 30, 36],
    'Salary': [30000, 40000, 50000, 70000]
}
df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)
# Out:
# Series:
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64
#
# DataFrame:
#       Name  Age  Salary
# 0   mithra   20   30000
# 1    srija   28   40000
# 2  samveda   30   50000
# 3   mohana   36   70000

# %%
array = np.array([[1, 3], [5, 7], [9, 11]])
df_from_array = pd.DataFrame(array, columns=['Column1', 'Column2'])
print("\nDataFrame from NumPy array:")
print(df_from_array)
print("\nRow with label 1 using loc:")
print(df.loc[1])
# Out:
# DataFrame from NumPy array:
#    Column1  Column2
# 0        1        3
# 1        5        7
# 2        9       11
#
# Row with label 1 using loc:
# Name      srija
# Age          28
# Salary    40000
# Name: 1, dtype: object

# %%
print("\nFirst two rows using iloc:")
print(df.iloc[0:2])
print("\nSelect 'Name' column:")
print(df['Name'])
print("\nSelect 'Name' and 'Age' columns:")
print(df[['Name', 'Age']])
print("\nRows where Salary > 75000:")
print(df[df['Salary'] > 75000])
# Out:
# First two rows using iloc:
#      Name  Age  Salary
# 0  mithra   20   30000
# 1   srija   28   40000
#
# Select 'Name' column:
# 0     mithra
# 1      srija
# 2    samveda
# 3     mohana
# Name: Name, dtype: object
#
# Select 'Name' and 'Age' columns:
#       Name  Age
# 0   mithra   20
# 1    srija   28
# 2  samveda   30
# 3   mohana   36
#
# Rows where Salary > 75000:
# Empty DataFrame
# Columns: [Name, Age, Salary]
# Index: []

# %%
data_dirty = {
    'Name': ['srija', 'mithra',None, 'mohana'],
    'Age': [20, None, 33, 42],
    'Salary': [60000, 70000, None, 75000]
}
df_dirty = pd.DataFrame(data_dirty)
print("\nOriginal Dirty DataFrame:")
print(df_dirty)
# Out:
# Original Dirty DataFrame:
#      Name   Age   Salary
# 0   srija  20.0  60000.0
# 1  mithra   NaN  70000.0
# 2    None  33.0      NaN
# 3  mohana  42.0  75000.0

# %%
print("\nFill missing values with a specific value:")
print(df_dirty.fillna({'Name': 'Unknown', 'Age': df_dirty['Age'].mean(), 'Salary': 0}))
# Out:
# Fill missing values with a specific value:
#       Name        Age   Salary
# 0    srija  20.000000  60000.0
# 1   mithra  31.666667  70000.0
# 2  Unknown  33.000000      0.0
# 3   mohana  42.000000  75000.0

# %%
print("\nBoolean DataFrame for missing values:")
print(df_dirty.isnull())
# Out:
# Boolean DataFrame for missing values:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False  False   False

# %%
df['Bonus'] = df['Salary'] * 0.1
print("\nDataFrame with Bonus column:")
print(df)
print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))
print("\nGroup by operation (average salary by age > 20 or not):")
df['AgeGroup'] = df['Age'] > 20
print(df.groupby('AgeGroup')['Salary'].mean())
# Out:
# DataFrame with Bonus column:
#       Name  Age  Salary   Bonus
# 0    Alice   20   30000  3000.0
# 1      Bob   28   40000  4000.0
# 2  Charlie   30   50000  5000.0
# 3    David   36   70000  7000.0
#
# Rename columns:
#       Name  Age  BaseSalary   Bonus
# 0    Alice   20       30000  3000.0
# 1      Bob   28       40000  4000.0
# 2  Charlie   30       50000  5000.0
# 3    David   36       70000  7000.0
#
# Sort by Age descending:
#       Name  Age  Salary   Bonus
# 3    David   36   70000  7000.0
# 2  Charlie   30   50000  5000.0
# 1      Bob   28   40000  4000.0
# 0    Alice   20   30000  3000.0
#
# Group by operation (average salary by age > 20 or not):
# AgeGroup
# False    30000.000000
# True     53333.333333
# Name: Salary, dtype: float64

# %%
print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
# Out:
# Rename columns:
#       Name  Age  BaseSalary
# 0   mithra   20       30000
# 1    srija   28       40000
# 2  samveda   30       50000
# 3   mohana   36       70000

# %%
import pandas as pd
import numpy as np
np.random.seed(1)
num_rows = 10
df_synth = pd.DataFrame({
    'ID': np.arange(1, num_rows + 1),
    'Score': np.random.randint(50, 100, size=num_rows),
    'Passed': np.random.choice([True, False], size=num_rows)
})
print("\nSynthetic DataFrame:")
print(df_synth)
# Out:
# Synthetic DataFrame:
#    ID  Score  Passed
# 0   1     87   False
# 1   2     93    True
# 2   3     62   False
# 3   4     58   False
# 4   5     59    True
# 5   6     61    True
# 6   7     55   False
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True

# %%
print("\nStudents who passed:")
print(df_synth[df_synth['Passed'] == True])
print("\nAverage score of failed students:")
print(df_synth[df_synth['Passed'] == False]['Score'].mean())
# Out:
# Students who passed:
#    ID  Score  Passed
# 1   2     93    True
# 4   5     59    True
# 5   6     61    True
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True
#
# Average score of failed students:
# 65.5

# %%
print("\nDataFrame info:")
df.info()
print("\nDataFrame describe:")
print(df.describe())
# Out:
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes
#
# DataFrame describe:
#              Age        Salary
# count   4.000000      4.000000
# mean   28.500000  47500.000000
# std     6.608076  17078.251277
# min    20.000000  30000.000000
# 25%    26.000000  37500.000000
# 50%    29.000000  45000.000000
# 75%    31.500000  55000.000000
# max    36.000000  70000.000000

# %%
print("\nData types of each column:")
print(df.dtypes)
print("\nFirst 3 rows:")
print(df.head(3))
print("\nLast 2 rows:")
print(df.tail(2))
# Out:
# Data types of each column:
# Name      object
# Age        int64
# Salary     int64
# dtype: object
#
# First 3 rows:
#       Name  Age  Salary
# 0   mithra   20   30000
# 1    srija   28   40000
# 2  samveda   30   50000
#
# Last 2 rows:
#       Name  Age  Salary
# 2  samveda   30   50000
# 3   mohana   36   70000

# %%
print("\nMean Age:", df['Age'].mean())
print("Median Salary:", df['Salary'].median())
print("Mode of Bonus:")
print("Standard Deviation of Salary:", df['Salary'].std())
print("Variance of Salary:", df['Salary'].var())
# Out:
# Mean Age: 28.5
# Median Salary: 45000.0
# Mode of Bonus:
# Standard Deviation of Salary: 17078.25127659933
# Variance of Salary: 291666666.6666667

# %%
print("\nCorrelation between Age and Salary:")
print(df[['Age', 'Salary']].corr())
print("\nCovariance between Age and Salary:")
print(df[['Age', 'Salary']].cov())
print("\nValue counts for Age:")
print(df['Age'].value_counts())
# Out:
# Correlation between Age and Salary:
#              Age    Salary
# Age     1.000000  0.959939
# Salary  0.959939  1.000000
#
# Covariance between Age and Salary:
#                   Age        Salary
# Age         43.666667  1.083333e+05
# Salary  108333.333333  2.916667e+08
#
# Value counts for Age:
# Age
# 20    1
# 28    1
# 30    1
# 36    1
# Name: count, dtype: int64

# %%
print("\nCumulative sum of Salary:")
print(df['Salary'].cumsum())
print("\nCumulative max of Salary:")
print(df['Salary'].cummax())
print("\nRank of Salary:")
print(df['Salary'].rank())
print("\nQuantiles of Salary:")
print(df['Salary'].quantile([0.25, 0.5, 0.75]))
# Out:
# Cumulative sum of Salary:
# 0     30000
# 1     70000
# 2    120000
# 3    190000
# Name: Salary, dtype: int64
#
# Cumulative max of Salary:
# 0    30000
# 1    40000
# 2    50000
# 3    70000
# Name: Salary, dtype: int64
#
# Rank of Salary:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: Salary, dtype: float64
#
# Quantiles of Salary:
# 0.25    37500.0
# 0.50    45000.0
# 0.75    55000.0
# Name: Salary, dtype: float64
